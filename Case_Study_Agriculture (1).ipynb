# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/content/IAS.csv")

# %%
data
# Out:
#        RowID      State_Name  District_Name  Crop_Year       Season  \
# 0          0           Bihar        NALANDA       2005  Rabi
# 1          1           Assam  KARBI ANGLONG       2019  Whole Year
# 2          2         Gujarat          ANAND       2020  Summer
# 3          3       Karnataka   UTTAR KANNAD       2013  Rabi
# 4          4   Uttar Pradesh        JAUNPUR       2016  Rabi
# ...      ...             ...            ...        ...          ...
# 73822  73822           Bihar          BUXAR       2012  Whole Year
# 73823  73823  Madhya Pradesh        RAJGARH       2021  Kharif
# 73824  73824  Madhya Pradesh        RAJGARH       2006  Kharif
# 73825  73825       Rajasthan           TONK       2008  Kharif
# 73826  73826       Jharkhand        KODERMA       2010  Winter
#
#             Crop      Area  Production
# 0          Wheat  81934.00   160425.00
# 1          Onion    257.00      514.00
# 2          Maize    100.00      100.00
# ...

# %%
data.describe()
# Out:
#               RowID     Crop_Year          Area    Production
# count  73827.000000  73827.000000  7.382700e+04  7.273100e+04
# mean   36913.000000   2013.657551  1.218297e+04  6.210320e+05
# std    21312.163499      4.954910  5.348285e+04  1.749756e+07
# min        0.000000   2005.000000  4.000000e-02  0.000000e+00
# 25%    18456.500000   2010.000000  8.100000e+01  8.900000e+01
# 50%    36913.000000   2014.000000  5.900000e+02  7.290000e+02
# 75%    55369.500000   2018.000000  4.500000e+03  7.200000e+03
# max    73826.000000   2023.000000  8.580100e+06  1.125000e+09

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73827 entries, 0 to 73826
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   RowID          73827 non-null  int64
#  1   State_Name     73827 non-null  object
#  2   District_Name  73827 non-null  object
#  3   Crop_Year      73827 non-null  int64
#  4   Season         73827 non-null  object
#  5   Crop           73827 non-null  object
#  6   Area           73827 non-null  float64
#  7   Production     72731 non-null  float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 4.5+ MB

# %%
data.isnull()
# Out:
#        RowID  State_Name  District_Name  Crop_Year  Season   Crop   Area  \
# 0      False       False          False      False   False  False  False
# 1      False       False          False      False   False  False  False
# 2      False       False          False      False   False  False  False
# 3      False       False          False      False   False  False  False
# 4      False       False          False      False   False  False  False
# ...      ...         ...            ...        ...     ...    ...    ...
# 73822  False       False          False      False   False  False  False
# 73823  False       False          False      False   False  False  False
# 73824  False       False          False      False   False  False  False
# 73825  False       False          False      False   False  False  False
# 73826  False       False          False      False   False  False  False
#
#        Production
# 0           False
# 1           False
# 2           False
# ...

# %%
data.isnull().sum()
# Out:
# RowID               0
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       1096
# dtype: int64

# %%
data.dtypes
# Out:
# RowID              int64
# State_Name        object
# District_Name     object
# Crop_Year          int64
# Season            object
# Crop              object
# Area             float64
# Production       float64
# dtype: object

# %%
# We want to replace the values with null values.
data['Production'].replace(0, np.nan, inplace=True)
data
# Out:
# <ipython-input-28-9b887eebaa0e>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Production'].replace(0, np.nan, inplace=True)
#        RowID      State_Name  District_Name  Crop_Year       Season  \
# 0          0           Bihar        NALANDA       2005  Rabi
# 1          1           Assam  KARBI ANGLONG       2019  Whole Year
# 2          2         Gujarat          ANAND       2020  Summer
# 3          3       Karnataka   UTTAR KANNAD       2013  Rabi
# ...

# %%
data.isnull().sum()
# Out:
# RowID               0
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       2147
# dtype: int64

# %%
data.columns
# Out:
# Index(['RowID', 'State_Name', 'District_Name', 'Crop_Year', 'Season', 'Crop',
#        'Area', 'Production'],
#       dtype='object')

# %%
# i want all the values of production column to be zero
data['Production'].fillna(0, inplace=True)
data
# Out:
# <ipython-input-31-eef7bc86d4cc>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Production'].fillna(0, inplace=True)
#        RowID      State_Name  District_Name  Crop_Year       Season  \
# 0          0           Bihar        NALANDA       2005  Rabi
# 1          1           Assam  KARBI ANGLONG       2019  Whole Year
# 2          2         Gujarat          ANAND       2020  Summer
# 3          3       Karnataka   UTTAR KANNAD       2013  Rabi
# 4          4   Uttar Pradesh        JAUNPUR       2016  Rabi
# ...

# %%
data.isnull().sum()
# Out:
# RowID            0
# State_Name       0
# District_Name    0
# Crop_Year        0
# Season           0
# Crop             0
# Area             0
# Production       0
# dtype: int64

# %%
data.shape
# Out:
# (73827, 8)

# %%
# Graph using matplotlib
plt.plot(data['Crop_Year'], data['Production'])
plt.xlabel('Year')
plt.ylabel('Production')
plt.title('Year vs Production')
plt.show()

# %%
# in which year the production was maximum
data['Production'].max()
# Out:
# 1125000000.0

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(data=data)
plt.xticks(rotation=90)
plt.title('Box plot for all columns')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_csv("/content/IAS.csv")

# state wise production
state_production=data.groupby('State_Name')['Production'].sum().reset_index()
state_production
# Out:
#                      State_Name    Production
# 0   Andaman and Nicobar Islands  2.936291e+08
# 1                Andhra Pradesh  3.595973e+09
# 2             Arunachal Pradesh  2.181652e+06
# 3                         Assam  6.019920e+08
# 4                         Bihar  1.125670e+08
# 5                    Chandigarh  2.923000e+04
# 6                  Chhattisgarh  3.260849e+07
# 7        Dadra and Nagar Haveli  6.919730e+05
# 8                           Goa  2.367726e+08
# 9                       Gujarat  1.500758e+08
# 10                      Haryana  9.644999e+07
# 11             Himachal Pradesh  5.828741e+06
# 12           Jammu and Kashmir   3.870168e+06
# 13                    Jharkhand  3.416858e+06
# 14                    Karnataka  2.640385e+08
# 15                       Kerala  3.314056e+10
# 16               Madhya Pradesh  1.300390e+08
# 17                  Maharashtra  3.621771e+08
# 18                      Manipur  1.560800e+06
# ...

# %%
# in whaich year the production was maximum
data[data['Production']==data['Production'].max()]
# Out:
#        RowID State_Name District_Name  Crop_Year       Season      Crop  \
# 47698  47698     Kerala    MALAPPURAM       2020  Whole Year   Coconut
#
#            Area    Production
# 47698  102417.0  1.125000e+09

# %%
# seasonwise production
season_production=data.groupby('Season')['Production'].sum().reset_index()
season_production
# Out:
#         Season    Production
# 0  Autumn       1.969044e+07
# 1  Kharif       1.195933e+09
# 2  Rabi         6.151127e+08
# 3  Summer       4.920665e+07
# 4  Whole Year   4.315616e+10
# 5  Winter       1.321746e+08

# %%
# season wise production including year
season_production=data.groupby(['Season', 'Crop_Year'])['Production'].sum().reset_index()
season_production
# Out:
#           Season  Crop_Year   Production
# 0    Autumn            2005    917563.00
# 1    Autumn            2006    448203.00
# 2    Autumn            2007    593151.00
# 3    Autumn            2008   2656136.00
# 4    Autumn            2009   2125591.00
# ..           ...        ...          ...
# 108  Winter            2019   9483749.64
# 109  Winter            2020  10397058.00
# 110  Winter            2021  10672463.40
# 111  Winter            2022  10412927.60
# 112  Winter            2023   1979371.50
#
# [113 rows x 3 columns]

# %%
# suppose i am a farmer which crop should be suitable for me in which season and in which state and district
crop_state=data.groupby(['Crop', 'State_Name', 'District_Name'])['Production'].sum().reset_index()
crop_state
# Out:
#                       Crop   State_Name     District_Name  Production
# 0                    Apple   Tamil Nadu          DINDIGUL         0.0
# 1      Arcanut (Processed)    Karnataka           BELLARY        43.0
# 2      Arcanut (Processed)    Karnataka    CHAMARAJANAGAR       198.0
# 3      Arcanut (Processed)    Karnataka            KODAGU      1863.0
# 4      Arcanut (Processed)    Karnataka           SHIMOGA     40216.0
# ...                    ...          ...               ...         ...
# 18397       other oilseeds  Uttarakhand       PITHORAGARH        89.0
# 18398       other oilseeds  Uttarakhand      RUDRA PRAYAG         0.0
# 18399       other oilseeds  Uttarakhand     TEHRI GARHWAL        75.0
# 18400       other oilseeds  Uttarakhand  UDAM SINGH NAGAR        31.0
# 18401       other oilseeds  Uttarakhand       UTTAR KASHI         1.0
#
# [18402 rows x 4 columns]

# %%
# find relation between area and production in line
plt.plot(data['Area'], data['Production'])
plt.xlabel('Area')
plt.ylabel('Production')
plt.title('Area vs Production')
plt.show()
